# %%
import pandas as pd
from sqlalchemy import create_engine
from sqlalchemy.engine import URL
import psycopg2

# %%
#Import CSV File
df_PerthHouses = pd.read_csv("..//Resources/AllPerth.csv")
df_PerthHouses.head()
# Out:
#            ADDRESS      SUBURB   PRICE  BEDROOMS  BATHROOMS  GARAGE  \
# 0    1 Acorn Place  South Lake  565000         4          2     2.0
# 1      1 Addis Way       Wandi  365000         3          2     2.0
# 2  1 Ainsley Court     Camillo  287000         3          1     1.0
# 3  1 Albert Street    Bellevue  255000         2          1     2.0
# 4     1 Aman Place   Lockridge  325000         4          1     2.0
#
#    LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST               NEAREST_STN  \
# 0        600         160      2003.0     18300  Cockburn Central Station
# 1        351         139      2013.0     26900           Kwinana Station
# 2        719          86      1979.0     22600           Challis Station
# 3        651          59      1953.0     17900           Midland Station
# 4        466         131      1998.0     11200        Bassendean Station
#
#    NEAREST_STN_DIST  DATE_SOLD  POSTCODE   LATITUDE   LONGITUDE  \
# ...

# %%
df_clean = df_PerthHouses[["PRICE","BEDROOMS","BATHROOMS","GARAGE","LAND_AREA","CBD_DIST","NEAREST_SCH_RANK","NEAREST_STN_DIST"]].dropna()
df_clean.head()
# Out:
#      PRICE  BEDROOMS  BATHROOMS  GARAGE  LAND_AREA  CBD_DIST  \
# 1   365000         3          2     2.0        351     26900
# 2   287000         3          1     1.0        719     22600
# 9   685000         3          2     8.0        552      5900
# 11  367500         3          2     2.0        398     36300
# 13  535000         4          2     4.0        704     23100
#
#     NEAREST_SCH_RANK  NEAREST_STN_DIST
# 1              129.0              4900
# 2              113.0              1900
# 9               29.0               508
# 11              39.0              2100
# 13             129.0              3900

# %%
len(df_clean)
# Out:
# 21066

# %%
df_PerthHouses.count()
# Out:
# ADDRESS             33656
# SUBURB              33656
# PRICE               33656
# BEDROOMS            33656
# BATHROOMS           33656
# GARAGE              31178
# LAND_AREA           33656
# FLOOR_AREA          33656
# BUILD_YEAR          30501
# CBD_DIST            33656
# NEAREST_STN         33656
# NEAREST_STN_DIST    33656
# DATE_SOLD           33656
# POSTCODE            33656
# LATITUDE            33656
# LONGITUDE           33656
# NEAREST_SCH         33656
# NEAREST_SCH_DIST    33656
# NEAREST_SCH_RANK    22704
# dtype: int64

# %%
#making a connection to the database 
rds_connection_string = "postgres:"+ "@localhost:5432/PerthHouses_overview_db"
rds_connection_string
# Out:
# 'postgres:@localhost:5432/PerthHouses_overview_db'

# %%
engine = create_engine('postgresql://postgres:postgres@localhost/PerthHouses_overview_db')
engine
# Out:
# Engine(postgresql://postgres:***@localhost/PerthHouses_overview_db)

# %%
df_PerthHouses.to_sql('perthhouses_overview', engine, if_exists='append')

# %%
pd.read_sql('select * from perthhouses_overview', con=engine)
# Out:
#         index             ADDRESS           SUBURB    PRICE  BEDROOMS  \
# 0           0       1 Acorn Place       South Lake   565000         4
# 1           1         1 Addis Way            Wandi   365000         3
# 2           2     1 Ainsley Court          Camillo   287000         3
# 3           3     1 Albert Street         Bellevue   255000         2
# 4           4        1 Aman Place        Lockridge   325000         4
# ...       ...                 ...              ...      ...       ...
# 336555  33651      9C Gold Street  South Fremantle  1040000         4
# 336556  33652      9C Pycombe Way      Westminster   410000         3
# 336557  33653      9D Pycombe Way      Westminster   427000         3
# 336558  33654     9D Shalford Way       Girrawheen   295000         3
# 336559  33655  9E Margaret Street          Midland   295000         3
#
#         BATHROOMS  GARAGE  LAND_AREA  FLOOR_AREA  BUILD_YEAR  CBD_DIST  \
# ...

# %%
X = df_clean[[
    "BEDROOMS", 
    "BATHROOMS",  
    "LAND_AREA", 
    "CBD_DIST",
    "GARAGE",
    "NEAREST_SCH_RANK",
    "NEAREST_STN_DIST"]]

y = df_clean["PRICE"].values.reshape(-1,1)

# %%
from sklearn.model_selection import train_test_split
X_train, X_test, y_train, y_test = train_test_split(X, y, random_state=42)

# %%
from sklearn.preprocessing import StandardScaler
X_scaler = StandardScaler().fit(X_train)
y_scaler = StandardScaler().fit(y_train)

# %%
# scale data
X_train_scaled = X_scaler.transform(X_train)
X_test_scaled = X_scaler.transform(X_test)
y_train_scaled = y_scaler.transform(y_train)
y_test_scaled = y_scaler.transform(y_test)

# %%
# train the model 
from sklearn.linear_model import LinearRegression
model = LinearRegression()
model.fit(X_train_scaled, y_train_scaled)
model.score(X_test_scaled, y_test_scaled)
# Out:
# 0.4314865276512776

# %%
# create a prediction function 
def predict(model, X_scaler, y_scaler, user_inputs):
    # get the user input data 
    BEDROOMS = user_inputs["BEDROOMS"]
    BATHROOMS= user_inputs["BATHROOMS"]
    LAND_AREA= user_inputs["LAND_AREA"]
    CBD_DIST= user_inputs["CBD_DIST"]
    GARAGE = user_inputs["GARAGE"]
    NEAREST_SCH_RANK = user_inputs["NEAREST_SCH_RANK"]
    NEAREST_STN_DIST = user_inputs["NEAREST_STN_DIST"]
    
    
    # store the input values into df 
    input_df = pd.DataFrame({
      "BEDROOMS":[BEDROOMS],
      "BATHROOMS": [BATHROOMS],
      "LAND_AREA": [LAND_AREA],
      "CBD_DIST":[CBD_DIST],
      "GARAGE" :[GARAGE],
      "NEAREST_SCH_RANK":[NEAREST_SCH_RANK],
      "NEAREST_STN_DIST": [NEAREST_STN_DIST]})
    
   

  
    # scale the X input df 
    X_scaled = X_scaler.transform(input_df)

    # obtain prediction (y) 
    prediction_scaled = model.predict(X_scaled)
    
    # scale prediction to human readable terms i.e. celcius 
    prediction = y_scaler.inverse_transform(prediction_scaled)
    return prediction

# %%
# test a single prediction 
user_inputs = {
   "BEDROOMS":4,
      "BATHROOMS":2,
      "LAND_AREA": 500,
      "FLOOR_AREA":250,
      "CBD_DIST":18000,
      "GARAGE" :2.0,
      "NEAREST_SCH_RANK":25.0,
      "NEAREST_STN_DIST" :1800 
}
print(f"predicted price is: ${predict(model, X_scaler, y_scaler, user_inputs)[0][0].round(2)}")
# Out:
# predicted price is: $894943.84

# %%
# save model 
import joblib 
joblib.dump(model, "../app/static/model.sav")
joblib.dump(y_scaler, "../app/static/y_scaler.sav")
joblib.dump(X_scaler, "../app/static/x_scaler.sav")
# Out:
# ['../app/static/x_scaler.sav']
